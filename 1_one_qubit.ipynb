# %%
from qiskit import QuantumCircuit

# Create a quantum circuit with one qubit
qc = QuantumCircuit(1)
# Apply H gate to qubit 0
qc.h(0)
# Measure qubits
qc.measure_all()
# Draw the circuit
qc.draw()
# Out:
#         ┌───┐ ░ ┌─┐
#      q: ┤ H ├─░─┤M├
#         └───┘ ░ └╥┘
# meas: 1/═════════╩═
#                  0

# %%
# Draw it nicer
qc.draw(output='mpl')
